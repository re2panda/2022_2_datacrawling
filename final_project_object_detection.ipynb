# %% [markdown]
# # Setting
#
# * Download Yolo v5
# * unzip the train_data file

# %%
# Download Yolo V5

# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-42-g5545ff3 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %%
# unzip train_data
# !unzip -q ../train_data.zip -d ../
# Out:
# images/train/간선버스162_1.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд162_1.jpg),
#          continuing with "central" filename version
# images/train/간선버스170.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд170.jpg),
#          continuing with "central" filename version
# images/train/간선버스170_1.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд170_1.jpg),
#          continuing with "central" filename version
# images/train/간선버스178.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд178.jpg),
#          continuing with "central" filename version
# images/train/간선버스187.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд187.jpg),
#          continuing with "central" filename version
# images/train/간선버스189.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд189.jpg),
#          continuing with "central" filename version
# images/train/간선버스199.jpg:  mismatching "local" filename (images/train/ъ░ДьДаы▓ДьКд199.jpg),
# ...

# %% [markdown]
# # Custom Data Training

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 40 --epochs 200 --data custom_data.yaml --weights yolov5m.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=40, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/ultralytics/yolov5
#    30cfa17..a5d83b2  exp13      -> origin/exp13
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# # Test
# * test the trained model

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --img 640 --conf 0.25 --source /content/test_file/test_vid_2.avi
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], source=/content/test_file/test_vid_2.avi, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-42-g5545ff3 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20861016 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/154) /content/test_file/test_vid_2.avi: 640x384 1 person, 1 greenbus, 23.1ms
# video 1/1 (2/154) /content/test_file/test_vid_2.avi: 640x384 1 person, 1 greenbus, 22.9ms
# video 1/1 (3/154) /content/test_file/test_vid_2.avi: 640x384 1 person, 1 greenbus, 23.0ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --img 640 --conf 0.25 --source /content/test_file/test_vid_1.avi
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], source=/content/test_file/test_vid_1.avi, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-42-g5545ff3 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20861016 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/597) /content/test_file/test_vid_1.avi: 640x384 1 person, 23.1ms
# video 1/1 (2/597) /content/test_file/test_vid_1.avi: 640x384 1 person, 22.9ms
# video 1/1 (3/597) /content/test_file/test_vid_1.avi: 640x384 1 person, 22.9ms
# ...
